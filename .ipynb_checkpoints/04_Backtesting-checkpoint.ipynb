# %% [markdown]
# # Información y Programación Financiera, TI, Algoritmos y Ciencia de Datos

# %%
# Información y Programación Financiera, TI, Algoritmos y Ciencia de Datos

# %% [markdown]
# Neftalí Valdez
#
# <a href="http://twitter.com/neftalivldz" target="_blank">@neftalivldz</a> | <a href="mailto:nvaldez@tec.mx">nvaldez@tec.mx</a>

# %%
# %pip install lseg.data
# Out:
# Collecting lseg.data
#   Downloading lseg_data-2.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: appdirs~=1.4.4 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (1.4.4)
# Requirement already satisfied: pyee<=12,>=9.0.4 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (11.1.0)
# Collecting httpx<0.28,>=0.18.0 (from lseg.data)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpcore<1.1.0 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (1.0.5)
# Requirement already satisfied: numpy in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (1.26.4)
# Requirement already satisfied: pandas<3.0,>=2.0 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (2.2.3)
# Requirement already satisfied: python-dateutil in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (2.9.0)
# Requirement already satisfied: requests in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (2.32.3)
# Requirement already satisfied: scipy in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (1.14.1)
# Requirement already satisfied: tenacity in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (8.5.0)
# Requirement already satisfied: watchdog in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (2.3.1)
# Requirement already satisfied: websocket-client!=1.5.0,!=1.5.2,>=1.5 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (1.8.0)
# Requirement already satisfied: pyhumps<4.0.0,>=3.0.2 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (3.8.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.3 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (3.1.4)
# Requirement already satisfied: simplejson in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from lseg.data) (3.19.3)
# Requirement already satisfied: certifi in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from httpcore<1.1.0->lseg.data) (2025.4.26)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from httpcore<1.1.0->lseg.data) (0.14.0)
# Requirement already satisfied: anyio in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from httpx<0.28,>=0.18.0->lseg.data) (4.4.0)
# Requirement already satisfied: idna in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from httpx<0.28,>=0.18.0->lseg.data) (2.10)
# Requirement already satisfied: sniffio in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from httpx<0.28,>=0.18.0->lseg.data) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.0.3->lseg.data) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from pandas<3.0,>=2.0->lseg.data) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from pandas<3.0,>=2.0->lseg.data) (2024.1)
# Requirement already satisfied: typing-extensions in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from pyee<=12,>=9.0.4->lseg.data) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from python-dateutil->lseg.data) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from requests->lseg.data) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages (from requests->lseg.data) (2.2.2)
# Downloading lseg_data-2.1.1-py3-none-any.whl (872 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.3/872.3 kB 5.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Installing collected packages: httpx, lseg.data
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [lseg.data]━ 1/2 [lseg.data]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# eikon 1.1.18 requires h2==4.*, which is not installed.
# Successfully installed httpx-0.27.2 lseg.data-2.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["LD_LIB_CONFIG_PATH"] = "../../Configuration"

# %%
import lseg.data as ld
import pandas_ta as ta
import matplotlib.pyplot as plt
import numpy as np

# %%
config = ld.get_config()
config.set_param("logs.transports.file.enabled", True)
config.set_param("logs.transports.file.name", "lseg-data-lib.log")
config.set_param("logs.level", "debug")

# %%
import lseg.data as ld
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x161dcbc10 {name='workspace'}>

# %%
from httpx._utils import get_environment_proxies

get_environment_proxies()
# Out:
# {}

# %%
import httpx
>>> httpx.__version__
# Out:
# '0.28.1'

# %%
from datetime import datetime, timedelta
today = datetime.today()
start_date = today - timedelta(days=(365*2))
print(today, start_date)
df = ld.get_history(universe=["TSLA.O"], fields=['TR.CLOSEPRICE'], interval="1D",
               start = start_date, end = today)
df = df.rename(columns = {"Close Price":"close"}) #renaming the columns of the dataset
df
# Out:
# 2025-05-27 23:29:22.810726 2023-05-28 23:29:22.810726
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 5
#       3 start_date = today - timedelta(days=(365*2))
#       4 print(today, start_date)
# ----> 5 df = ld.get_history(universe=["TSLA.O"], fields=['TR.CLOSEPRICE'], interval="1D",
#       6                start = start_date, end = today)
#       7 df = df.rename(columns = {"Close Price":"close"}) #renaming the columns of the dataset
#       8 df
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/_access_layer/get_history_func.py:114, in get_history(universe, fields, interval, start, end, adjustments, count, parameters, header_type)
#     112 universe = UniverseContainer(universe)
#     113 fields = FieldsContainer(fields)
# --> 114 data_grid_type = get_data_grid_type_by_session(session)
#     115 hp = get_context(ContextType.HP, universe, fields)
#     116 adc = get_context(ContextType.GetHistoryADC, universe, fields, header_type, data_grid_type)
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/content/fundamental_and_reference/_data_grid_type.py:66, in get_data_grid_type_by_session(session)
#      65 def get_data_grid_type_by_session(session: "Session") -> DataGridType:
# ---> 66     content_type, _ = determine_content_type_and_flag(session)
#      67     return get_data_grid_type(content_type)
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/content/fundamental_and_reference/_data_grid_type.py:52, in determine_content_type_and_flag(session)
#      51 def determine_content_type_and_flag(session: "Session") -> Tuple["ContentType", bool]:
# ---> 52     content_type = get_content_type(session)
#      53     changed = False
#      55     if is_platform_session(session) and content_type in {
#      56         ContentType.DATA_GRID_UDF,
#      57         ContentType.DATA_GRID_UDF_EIKON_APPROACH,
#      58     }:
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/content/fundamental_and_reference/_data_grid_type.py:42, in get_content_type(session)
#      41 def get_content_type(session: "Session") -> ContentType:
# ---> 42     from ...delivery._data._data_provider_factory import get_api_config
#      44     config = get_api_config(ContentType.DATA_GRID_RDP, session.config)
#      45     name_platform = config.setdefault("underlying-platform", DataGridType.RDP)
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/delivery/_data/_data_provider_factory.py:40
#      31 from ...content.fundamental_and_reference._data_provider import (
#      32     data_grid_rdp_data_provider,
#      33     data_grid_udf_data_provider,
#      34     data_grid_udf_eikon_approach_data_provider,
#      35 )
#      36 from ...content.historical_pricing._historical_pricing_data_provider import (
#      37     hp_events_data_provider,
#      38     hp_summaries_data_provider,
#      39 )
# ---> 40 from ...content.ipa.curves._curves_data_provider import (
#      41     cross_currency_curves_definitions_data_provider,
#      42     cross_currency_curves_definitions_delete_data_provider,
#      43     cross_currency_curves_triangulate_definitions_data_provider,
#      44     curve_data_provider,
#      45     curves_data_provider,
#      46     forward_curves_data_provider,
#      47 )
#      48 from ...content.ipa.dates_and_calendars.add_periods._add_periods_data_provider import add_period_data_provider
#      49 from ...content.ipa.dates_and_calendars.count_periods._count_periods_data_provider import count_periods_data_provider
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/content/ipa/curves/_curves_data_provider.py:6
#       2 from typing import Any, Callable, List, TYPE_CHECKING
#       4 import numpy as np
# ----> 6 from ._models._curve import Curve, ForwardCurve, ZcCurve
#       7 from .._content_validator import CurvesAndSurfacesContentValidator
#       8 from .._request_factory import CurvesAndSurfacesRequestFactory, get_type_by_axis
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/lseg/data/content/ipa/curves/_models/_curve.py:4
#       1 from typing import Union
#       3 import numpy as np
# ----> 4 from scipy import interpolate
#       6 from . import CurvePoint
#       7 from ..._request_factory import value_arg_parser
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File ~/miniforge3/envs/mlf/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#     170 # New interface to fitpack library:
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:8
#       5 import numpy as np
#       6 from numpy import array, asarray, intp, poly1d, searchsorted
# ----> 8 import scipy.special as spec
#       9 from scipy._lib._util import copy_if_needed
#      10 from scipy.special import comb
#
# File ~/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/__init__.py:807
#     802 _load_libsf_error_state()
#     805 from ._sf_error import SpecialFunctionWarning, SpecialFunctionError
# --> 807 from . import _ufuncs
#     808 from ._ufuncs import *
#     810 # Replace some function definitions from _ufuncs to add Array API support
#
# ImportError: dlopen(/Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/_ufuncs.cpython-311-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <0B9C315B-A1DD-3527-88DB-4B90531D343F> /Users/neftalivaldez/miniforge3/envs/mlf/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/neftalivaldez/miniforge3/envs/mlf/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/neftalivaldez/miniforge3/envs/mlf/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/libgfortran.5.dylib' (no such file), '/Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/libgfortran.5.dylib' (no such file), '/Users/neftalivaldez/miniforge3/envs/mlf/lib/python3.11/site-packages/scipy/special/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/neftalivaldez/miniforge3/envs/mlf/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/neftalivaldez/miniforge3/envs/mlf/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
for t in [5, 21, 63]:
    print(t)
# Out:
# 5
# 21
# 63

# %%
for t in [5, 21, 63]:
    df[f'SMA_{t}'] = ta.sma(df['close'],
                               length=t)

# %%
df
# Out:
# TSLA.O       close    SMA_5      SMA_21      SMA_63
# Date
# 2023-03-06  193.81      NaN         NaN         NaN
# 2023-03-07  187.71      NaN         NaN         NaN
# 2023-03-08   182.0      NaN         NaN         NaN
# 2023-03-09  172.92      NaN         NaN         NaN
# 2023-03-10  173.44  181.976         NaN         NaN
# ...            ...      ...         ...         ...
# 2025-02-26   290.8  323.266  359.075714  388.754286
# 2025-02-27  281.95  308.776  353.545238  387.633492
# 2025-02-28  292.98  299.812  348.968095  386.909524
# 2025-03-03  284.65  290.636  343.461905  386.059048
# 2025-03-04  272.04  284.484  337.149524  385.093175
#
# [501 rows x 4 columns]

# %%
plt.style.use('tableau-colorblind10')
# %config InlineBackend.figure_format = 'svg'

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Plot Closing Price and SMAs
plt.plot(df['close'], label='Close Price', alpha=0.5)
plt.plot(df['SMA_21'], label='21-Day SMA', alpha=0.75, color='blue')
plt.plot(df['SMA_63'], label='63-Day SMA', alpha=0.75, color='orange')

plt.title('Price with SMA')
plt.legend()
plt.show()

# %%
# Generate Buy and Sell signals
df['Buy_Signal'] = np.where((df['SMA_21'] > df['SMA_63']) & (df['SMA_21'].shift(1) <= df['SMA_63'].shift(1)), 1, 0)
df['Sell_Signal'] = np.where((df['SMA_21'] < df['SMA_63']) & (df['SMA_21'].shift(1) >= df['SMA_63'].shift(1)), -1, 0)

# Plotting
plt.figure(figsize=(12, 6))

# Plot Closing Price and SMAs
plt.plot(df['close'], label='Close Price', alpha=0.5)
plt.plot(df['SMA_21'], label='21-Day SMA', alpha=0.75, color='blue')
plt.plot(df['SMA_63'], label='63-Day SMA', alpha=0.75, color='orange')

# Plot Buy Signals
plt.plot(df[df['Buy_Signal'] == 1].index, df['close'][df['Buy_Signal'] == 1], '^', markersize=10, color='g', lw=0, label='Buy Signal')

# Plot Sell Signals
plt.plot(df[df['Sell_Signal'] == -1].index, df['close'][df['Sell_Signal'] == -1], 'v', markersize=10, color='r', lw=0, label='Sell Signal')

plt.title('Price with SMA Crossover Buy and Sell Signals')
plt.legend()
plt.show()

# %%
df['position'] = np.where((df['SMA_21'] > df['SMA_63']),  
                             1,  
                             -1)

# %%
from matplotlib.dates import AutoDateFormatter, AutoDateLocator


fig,ax1 = plt.subplots(figsize=(12, 6))
l1, = ax1.plot(df.index, df['close'], label='Close Price', alpha=0.5) #Your Price field
ax1.set_ylabel('Price (y1 axis)')
ax1.plot(df['SMA_21'], label='21-Day SMA', alpha=0.75, color='blue')
ax1.plot(df['SMA_63'], label='63-Day SMA', alpha=0.75, color='orange')
ax1.plot(df[df['Buy_Signal'] == 1].index, df['close'][df['Buy_Signal'] == 1], '^', markersize=10, color='g', lw=0, label='Buy Signal')
ax1.plot(df[df['Sell_Signal'] == -1].index, df['close'][df['Sell_Signal'] == -1], 'v', markersize=10, color='r', lw=0, label='Sell Signal')


ax2 = ax1.twinx() ##Using twinx to make ax2 as secondary axis for ax1
l2, = ax2.plot(df.index,df['position'], alpha=0.75, color='pink') #Your sales field
ax2.set_ylabel('Position')

fig.legend([l1, l2], ["Price", "Position"])

xtick_locator = AutoDateLocator()
xtick_formatter = AutoDateFormatter(xtick_locator)

ax1.xaxis.set_major_locator(xtick_locator)
ax1.xaxis.set_major_formatter(xtick_formatter)

# %%
df['Returns'] = np.log(df['close'] / df['close'].shift(1))
df['Strategy'] = df['position'].shift(1) * df['Returns']  
df.round(4).head()
# Out:
# TSLA.O       close    SMA_5  SMA_21  SMA_63  Buy_Signal  Sell_Signal  \
# Date
# 2023-03-06  193.81      NaN     NaN     NaN           0            0
# 2023-03-07  187.71      NaN     NaN     NaN           0            0
# 2023-03-08   182.0      NaN     NaN     NaN           0            0
# 2023-03-09  172.92      NaN     NaN     NaN           0            0
# 2023-03-10  173.44  181.976     NaN     NaN           0            0
#
# TSLA.O      position  Returns  Strategy
# Date
# 2023-03-06        -1     <NA>      <NA>
# 2023-03-07        -1   -0.032     0.032
# 2023-03-08        -1  -0.0309    0.0309
# 2023-03-09        -1  -0.0512    0.0512
# 2023-03-10        -1    0.003    -0.003

# %%
df.dropna(inplace=True)

# %%
np.exp(df[['Returns', 'Strategy']].sum())
# Out:
# TSLA.O
# Returns      1.31091
# Strategy    1.021609
# dtype: Float64

# %%
df[['Returns', 'Strategy']].std() * 252 ** 0.5
# Out:
# TSLA.O
# Returns     0.577803
# Strategy    0.577886
# dtype: Float64

# %%
ax1 = df[['Returns', 'Strategy']].cumsum(
        ).apply(np.exp).plot(figsize=(12,5))

ax2 = ax1.twinx() ##Using twinx to make ax2 as secondary axis for ax1
l2, = ax2.plot(df.index,df['position'], alpha=0.75, color='pink') #Your sales field
ax2.set_ylabel('Position')

fig.legend([l1, l2], ["Price", "Position"])

xtick_locator = AutoDateLocator()
xtick_formatter = AutoDateFormatter(xtick_locator)

ax1.xaxis.set_major_locator(xtick_locator)
ax1.xaxis.set_major_formatter(xtick_formatter)

ax1.get_legend().set_bbox_to_anchor((0.25, 0.85));
# plt.savefig('../../images/ch15/strat_plot_03.png');

# %% [markdown]
# ### Bibliography
#
# Vahid. Using Pandas_TA To Generate Technical Indicators And Signals https://pythonology.eu/using-pandas_ta-to-generate-technical-indicators-and-signals/
#
# Stefan Jansen. Machine learning for trading https://github.com/stefan-jansen/machine-learning-for-trading/blob/main/24_alpha_factor_library/02_common_alpha_factors.ipynb
#
# Ives Hilpisch. Python for Finance https://github.com/yhilpisch/py4fi2nd/blob/master/code/ch15/15_trading_strategies_a.ipynb
#
# Forecast Stock Price using RDP Historical Pricing with Facebook Prophet library https://github.com/LSEG-API-Samples/Article.RDPAPI.Python.PriceForcastUsingFBProPhet/blob/main/rdp_fbprophet.ipynb
