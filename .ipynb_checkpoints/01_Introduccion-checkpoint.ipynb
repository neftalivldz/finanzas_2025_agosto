# %% [markdown]
# # Información y Programación Financiera, TI, Algoritmos y Ciencia de Datos

# %% [markdown]
# Neftalí Valdez
#
# <a href="http://twitter.com/neftalivldz" target="_blank">@neftalivldz</a> | <a href="mailto:nvaldez@tec.mx">nvaldez@tec.mx</a>

# %%
#!pip install lseg.data
#!pip install matplotlib
#!pip install seaborn

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:52:34) [Clang 18.1.8 ]

# %%
import lseg.data as ld

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x10801be50 {name='workspace'}>

# %%
df = ld.get_data(
        universe=['IBM.N', 'VOD.L'], 
        fields=['BID', 'ASK', 'TR.Revenue']
    )
print(df)
# Out:
#   Instrument      Revenue     BID     ASK
# 0      IBM.N  62753000000  236.92  237.02
# 1      VOD.L  37448000000    84.0    87.0

# %%
import pandas as pdf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Numpy

# %%
# Python program to demonstrate
# basic array characteristics
import numpy as np
 
# Creating array object
arr = np.array( [[ 1, 2, 3],
                 [ 4, 2, 5]] )
 
# Printing type of arr object
print("Array is of type: ", type(arr))
 
# Printing array dimensions (axes)
print("No. of dimensions: ", arr.ndim)
 
# Printing shape of array
print("Shape of array: ", arr.shape)
 
# Printing size (total number of elements) of array
print("Size of array: ", arr.size)
 
# Printing type of elements in array
print("Array stores elements of type: ", arr.dtype)
# Out:
# Array is of type:  <class 'numpy.ndarray'>
# No. of dimensions:  2
# Shape of array:  (2, 3)
# Size of array:  6
# Array stores elements of type:  int64

# %%
arr = np.array( [[ 1, 2, 3],
                 [ 4, 2, 5]] )
arr[0][0]
# Out:
# np.int64(1)

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Python Pandas

# %%
import pandas as pd 

data = {
  "sesion": [420, 380, 390],
  "asistencia": [25, 20, 27]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
df
# Out:
#    sesion  asistencia
# 0     420          25
# 1     380          20
# 2     390          27

# %%
#utilización de índice:
print(df.loc[2])
# Out:
# sesion        390
# asistencia     27
# Name: 2, dtype: int64

# %%
df = pd.DataFrame(data, index = ["dia1", "dia2", "dia3"])
df
# Out:
#       sesion  asistencia
# dia1     420          25
# dia2     380          20
# dia3     390          27

# %% [markdown]
# # Refinitiv Python

# %% [markdown]
# # Extracción de datos estructurados

# %% [markdown]
# Las funciones básicas para extraer datos de eikon son las siguiente:
# - get_symbology
# - get_data
# - get_timeseries
#
# get_symbology(symbol, from_symbol_type='RIC', to_symbol_type=None, raw_output=False, debug=False, bestMatch=True)
# Devuelve una lista de nombre de instrumentos convertiods en el código del intrumento.
#
# get_data(instruments, fields, parameters=None, field_name=False, raw_output=False, debug=False)
# Devuelve un dataframe de pandas con campos en columnas e intrumentos como índice de renglones.
#
# get_timeseries(rics, fields='*', start_date=None, end_date=None, interval='daily', count=None, calendar=None, corax=None, normalize=False, raw_output=False, debug=False)
# Devuelve series históricas de uno o varios RICs.
# <br>
# Referencia: https://docs-developers.refinitiv.com/1594387995587/14684/book/en/eikon/index.html
# RICs Reuters instrument code

# %% [markdown]
# # Obtener datos

# %%
data = ld.get_data(["SPOT.K", "IBM", "GOOG.O", "MSFT.O"], ["TR.PriceClose", "TR.Volume", "TR.PriceLow", "TR.TotalReturnYTD"])

# %%
data
# Out:
#   Instrument  Price Close    Volume  Price Low  YTD Total Return
# 0     SPOT.K        695.0   1360257   682.0901          55.34892
# 1        IBM       240.07   5663562      236.2         11.447415
# 2     GOOG.O       203.03  19573041     198.64          6.864257
# 3     MSFT.O       520.58  19619160     519.37         23.979545

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # Obtener datos de un índice

# %%
dax = ld.get_data('0#.GDAXI', fields=['TR.CommonName', 'TR.PriceClose',
                                      'TR.Volume', 'TR.TotalReturnYTD'])

# %%
dax
# Out:
#    Instrument                                Company Common Name  Price Close  \
# 0    BASFn.DE                                            BASF SE        45.87
# 1    IFXGn.DE                           Infineon Technologies AG       36.615
# 2    SIEGn.DE                                         Siemens AG       233.25
# 3    EONGn.DE                                            E.ON SE       15.985
# 4    DBKGn.DE                                   Deutsche Bank AG       31.425
# 5   SATG_p.DE                                       Sartorius AG        197.0
# 6     SAPG.DE                                             SAP SE       239.65
# 7    BAYGn.DE                                           Bayer AG        26.63
# 8     RWEG.DE                                             RWE AG        34.58
# 9   HNKG_p.DE                                Henkel AG & Co KGaA        71.62
# 10    ZALG.DE                                         Zalando SE        23.47
# 11   DTEGn.DE                                Deutsche Telekom AG        30.65
# 12    MRCG.DE                                         Merck KGaA       110.95
# 13  PSHG_p.DE                       Porsche Automobil Holding SE        36.55
# 14  VOWG_p.DE                                      Volkswagen AG        98.86
# 15    BMWG.DE                        Bayerische Motoren Werke AG        88.84
# 16    BEIG.DE                                      Beiersdorf AG        101.1
# 17    HEIG.DE                            Heidelberg Materials AG        207.2
# 18    RHMG.DE                                     Rheinmetall AG       1641.0
# 19   MTXGn.DE                                MTU Aero Engines AG        389.7
# 20    FMEG.DE                          Fresenius Medical Care AG        42.55
# 21    FREG.DE                             Fresenius SE & Co KGaA        46.07
# 22    DHLn.DE                                   Deutsche Post AG        41.62
# 23    ALVG.DE                                         Allianz SE        376.6
# 24   MUVGn.DE  Muenchener Rueckversicherungs-Gesellschaft in ...        555.2
# 25    CONG.DE                                     Continental AG        74.56
# 26    SHLG.DE                            Siemens Healthineers AG        46.78
# 27    SY1G.DE                                         Symrise AG        79.66
# 28   ADSGn.DE                                          Adidas AG       167.85
# 29   HNRGn.DE                                  Hannover Rueck SE        255.2
# 30   DTGGe.DE                           Daimler Truck Holding AG        41.47
# 31   ENR1n.DE                                  Siemens Energy AG        97.82
# 32    MBGn.DE                             Mercedes-Benz Group AG        53.12
# 33   BNRGn.DE                                        Brenntag SE        54.22
# 34    CBKG.DE                                     Commerzbank AG        37.52
# 35    AIRG.DE                                          Airbus SE       183.72
# 36    VNAn.DE                                         Vonovia SE        28.73
# 37   DB1Gn.DE                                 Deutsche Boerse AG        257.0
# 38     QIA.DE                                          Qiagen NV        42.06
# 39  P911_p.DE                             Dr Ing hc F Porsche AG        45.76
#
#      Volume  YTD Total Return
# 0   2225025         13.306691
# 1   1996823         17.667943
# 2    659178         24.929257
# 3   3613441         47.576671
# 4   4456875         91.032655
# 5    123206         -8.407158
# 6   1095604          2.063876
# 7   1935706         39.423659
# 8   5536516          27.11406
# 9    447006        -12.573266
# 10  1079040        -27.292374
# 11  3548438          8.107441
# 12   270254         -19.19863
# 13   536732          6.195278
# 14   536571         18.031972
# 15   472873         18.504983
# 16   402891        -17.782309
# 17   203653         75.639894
# 18   222315         161.16587
# 19    71153         19.378786
# 20   453506         -0.955975
# 21  1021581          39.01854
# 22   973051         28.834272
# 23   764283         29.897842
# 24   225180         18.638611
# 25   189076         18.322781
# 26   674667         -7.686373
# 27   226870        -21.895666
# 28   352855        -28.406442
# 29   108159         10.055332
# 30   374430         18.510564
# 31  1762814         95.474395
# 32  1310434          6.275797
# 33   294273         -1.425524
# 34  5482459        140.274259
# 35   157980         18.881012
# 36  3221224          0.059745
# 37   271183         16.067633
# 38   317680         -1.637918
# 39   325932        -17.918692

# %%
dax[0:5]
# Out:
#   Instrument       Company Common Name  Price Close   Volume  YTD Total Return
# 0   BASFn.DE                   BASF SE        45.87  2225025         13.306691
# 1   IFXGn.DE  Infineon Technologies AG       36.615  1996823         17.667943
# 2   SIEGn.DE                Siemens AG       233.25   659178         24.929257
# 3   EONGn.DE                   E.ON SE       15.985  3613441         47.576671
# 4   DBKGn.DE          Deutsche Bank AG       31.425  4456875         91.032655

# %%
dax.set_index('Instrument')['YTD Total Return']
# Out:
# Instrument
# BASFn.DE      13.306691
# IFXGn.DE      17.667943
# SIEGn.DE      24.929257
# EONGn.DE      47.576671
# DBKGn.DE      91.032655
# SATG_p.DE     -8.407158
# SAPG.DE        2.063876
# BAYGn.DE      39.423659
# RWEG.DE        27.11406
# HNKG_p.DE    -12.573266
# ZALG.DE      -27.292374
# DTEGn.DE       8.107441
# MRCG.DE       -19.19863
# PSHG_p.DE      6.195278
# VOWG_p.DE     18.031972
# BMWG.DE       18.504983
# BEIG.DE      -17.782309
# HEIG.DE       75.639894
# RHMG.DE       161.16587
# MTXGn.DE      19.378786
# FMEG.DE       -0.955975
# FREG.DE        39.01854
# DHLn.DE       28.834272
# ALVG.DE       29.897842
# MUVGn.DE      18.638611
# CONG.DE       18.322781
# SHLG.DE       -7.686373
# SY1G.DE      -21.895666
# ADSGn.DE     -28.406442
# HNRGn.DE      10.055332
# DTGGe.DE      18.510564
# ENR1n.DE      95.474395
# MBGn.DE        6.275797
# BNRGn.DE      -1.425524
# CBKG.DE      140.274259
# AIRG.DE       18.881012
# VNAn.DE        0.059745
# DB1Gn.DE      16.067633
# QIA.DE        -1.637918
# P911_p.DE    -17.918692
# Name: YTD Total Return, dtype: Float64

# %%
dax2 = dax.set_index('Instrument')['YTD Total Return'].sort_values().to_frame()
dax2.columns = [c.replace(' ', '_') for c in dax2.columns]

# %%
plt.rcParams["figure.figsize"] = [12.50, 3.50]
plt.rcParams["figure.autolayout"] = True

dax2 = dax.set_index('Instrument')['YTD Total Return'].sort_values().to_frame()
dax2.columns = [c.replace(' ', '_') for c in dax2.columns]

bar_plot = sns.barplot(x=dax2.index, y=dax2['YTD_Total_Return'], color="#4CC9F0")
plt.xticks(rotation=90)
plt.show()

# %%
type(dax2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Generen grafico para volumen de menor a mayor DJI

# %%
lp4 = ld.get_data('LP40065886', ['TR.FundHoldingRIC','TR.FundHoldingName',
                           'TR.FundPercentageOfFundAssets',
                           'TR.FundNumberOfShares',
                           'TR.FundNumberOfSharesChanged'],
            {'Endnum':'5000'})

# %%
lp4
# Out:
#       Instrument Holding RIC                    Holding Name  \
# 0     LP40065886     MSFT.OQ              MICROSOFT CORP ORD
# 1     LP40065886     NVDA.OQ                 NVIDIA CORP ORD
# 2     LP40065886     AAPL.OQ                   APPLE INC ORD
# 3     LP40065886     AMZN.OQ              AMAZON.COM INC ORD
# 4     LP40065886     META.OQ          META PLATFORMS INC ORD
# ...          ...         ...                             ...
# 3177  LP40065886     LPCN.OQ                LIPOCINE INC ORD
# 3178  LP40065886     FGEN.OQ                FIBROGEN INC ORD
# 3179  LP40065886                  AMBIT BIOSCIENCES CORP CVR
# 3180  LP40065886              ALEXZA PHARMACEUTICALS INC CVR
# 3181  LP40065886     DRRX.OQ                 DURECT CORP ORD
#
#       Percentage of Fund Assets  Number of Shares  Number of Shares Changed
# 0                         6.207         3767450.0                  -17750.0
# 1                        6.1481        11748800.0                  -52958.0
# 2                        5.1446         7570312.0                  -78637.0
# 3                        3.5189         4842521.0                  -12928.0
# 4                        2.6901         1100372.0                  -14478.0
# ...                         ...               ...                       ...
# 3177                        0.0            3009.0                   -1400.0
# 3178                        0.0            2436.0                  -58482.0
# 3179                        0.0           29736.0                       0.0
# 3180                        0.0           80591.0                       0.0
# 3181                        0.0           15978.0                       0.0
#
# [3182 rows x 6 columns]

# %%
XLE= ld.get_data('XLE', ['TR.FundHoldingRIC','TR.FundHoldingName', 'TR.FundPercentageOfFundAssets',
                           'TR.FundNumberOfShares', 'TR.FundNumberOfSharesChanged'],
            {'Endnum':'5000'})

# %%
XLE
# Out:
#    Instrument Holding RIC                                       Holding Name  \
# 0         XLE       XOM.N                               EXXON MOBIL CORP ORD
# 1         XLE       CVX.N                                   CHEVRON CORP ORD
# 2         XLE       COP.N                                 CONOCOPHILLIPS ORD
# 3         XLE       WMB.N                         WILLIAMS COMPANIES INC ORD
# 4         XLE       EOG.N                              EOG RESOURCES INC ORD
# 5         XLE       KMI.N                              KINDER MORGAN INC ORD
# 6         XLE       MPC.N                        MARATHON PETROLEUM CORP ORD
# 7         XLE       OKE.N                                      ONEOK INC ORD
# 8         XLE       SLB.N                                SCHLUMBERGER NV ORD
# 9         XLE       PSX.N                                    PHILLIPS 66 ORD
# 10        XLE      BKR.OQ                                BAKER HUGHES CO ORD
# 11        XLE       VLO.N                             VALERO ENERGY CORP ORD
# 12        XLE      TRGP.N                           TARGA RESOURCES CORP ORD
# 13        XLE       EQT.N                                       EQT CORP ORD
# 14        XLE       OXY.N                      OCCIDENTAL PETROLEUM CORP ORD
# 15        XLE     FANG.OQ                         DIAMONDBACK ENERGY INC ORD
# 16        XLE      EXE.OQ                             EXPAND ENERGY CORP ORD
# 17        XLE       DVN.N                              DEVON ENERGY CORP ORD
# 18        XLE       HAL.N                                 HALLIBURTON CO ORD
# 19        XLE      CTRA.N                             COTERRA ENERGY INC ORD
# 20        XLE       TPL.N                        TEXAS PACIFIC LAND CORP ORD
# 21        XLE      APA.OQ                                  APA CORP (US) ORD
# 22        XLE      XAEU25                                    EMINI ENRGY U25
# 23        XLE  LP40206140  STATE STREET US GOVERNMENT MONEY MARKET FUND;INST
# 24        XLE                                                       USD CASH
# 25        XLE                                  OTHER ASSETS LESS LIABILITIES
#
#     Percentage of Fund Assets  Number of Shares  Number of Shares Changed
# 0                     23.0299        56295820.0                 -584164.0
# 1                     18.0806        32538942.0                 4696365.0
# 2                       7.483        21419230.0                 -222115.0
# 3                      4.4512        20262328.0                 -210112.0
# 4                      4.4155        10039920.0                 -104200.0
# 5                      3.9459        38376569.0                 -398041.0
# 6                      3.8034         6098701.0                  -63169.0
# 7                      3.7309        12399894.0                 -128562.0
# 8                      3.6902        29794541.0                 2513226.0
# 9                      3.6627         8088239.0                  -83928.0
# 10                     3.2468        19667907.0                 -203878.0
# 11                     3.1284         6217637.0                  -64437.0
# 12                      2.626         4306454.0                  -44699.0
# 13                     2.3406        11883617.0                 -123333.0
# 14                     2.2648        14066277.0                 -146084.0
# 15                     2.0221         3712029.0                  -38434.0
# 16                     1.6506         4299097.0                  -44532.0
# 17                     1.5517        12746706.0                 -132279.0
# 18                     1.4009        17066677.0                 -177138.0
# 19                     1.3542        15151930.0                 -157210.0
# 20                     1.3273          374140.0                   -3920.0
# 21                     0.5063         7163278.0                  -74312.0
# 22                     0.2115           62900.0                    3800.0
# 23                     0.1908       52068324.23               13587774.91
# 24                     0.0184        5007768.05               -1013963.39
# 25                    -0.1335              <NA>                      <NA>

# %%
XLE.columns = [c.replace(' ', '_') for c in XLE.columns]
list_values = ['USD CASH', 'OTHER ASSETS LESS LIABILITIES']
XLE[~XLE['Holding_Name'].isin(list_values)]
# Out:
#    Instrument Holding_RIC                                       Holding_Name  \
# 0         XLE       XOM.N                               EXXON MOBIL CORP ORD
# 1         XLE       CVX.N                                   CHEVRON CORP ORD
# 2         XLE       COP.N                                 CONOCOPHILLIPS ORD
# 3         XLE       WMB.N                         WILLIAMS COMPANIES INC ORD
# 4         XLE       EOG.N                              EOG RESOURCES INC ORD
# 5         XLE       KMI.N                              KINDER MORGAN INC ORD
# 6         XLE       MPC.N                        MARATHON PETROLEUM CORP ORD
# 7         XLE       OKE.N                                      ONEOK INC ORD
# 8         XLE       SLB.N                                SCHLUMBERGER NV ORD
# 9         XLE       PSX.N                                    PHILLIPS 66 ORD
# 10        XLE      BKR.OQ                                BAKER HUGHES CO ORD
# 11        XLE       VLO.N                             VALERO ENERGY CORP ORD
# 12        XLE      TRGP.N                           TARGA RESOURCES CORP ORD
# 13        XLE       EQT.N                                       EQT CORP ORD
# 14        XLE       OXY.N                      OCCIDENTAL PETROLEUM CORP ORD
# 15        XLE     FANG.OQ                         DIAMONDBACK ENERGY INC ORD
# 16        XLE      EXE.OQ                             EXPAND ENERGY CORP ORD
# 17        XLE       DVN.N                              DEVON ENERGY CORP ORD
# 18        XLE       HAL.N                                 HALLIBURTON CO ORD
# 19        XLE      CTRA.N                             COTERRA ENERGY INC ORD
# 20        XLE       TPL.N                        TEXAS PACIFIC LAND CORP ORD
# 21        XLE      APA.OQ                                  APA CORP (US) ORD
# 22        XLE      XAEU25                                    EMINI ENRGY U25
# 23        XLE  LP40206140  STATE STREET US GOVERNMENT MONEY MARKET FUND;INST
#
#     Percentage_of_Fund_Assets  Number_of_Shares  Number_of_Shares_Changed
# 0                     23.0299        56295820.0                 -584164.0
# 1                     18.0806        32538942.0                 4696365.0
# 2                       7.483        21419230.0                 -222115.0
# 3                      4.4512        20262328.0                 -210112.0
# 4                      4.4155        10039920.0                 -104200.0
# 5                      3.9459        38376569.0                 -398041.0
# 6                      3.8034         6098701.0                  -63169.0
# 7                      3.7309        12399894.0                 -128562.0
# 8                      3.6902        29794541.0                 2513226.0
# 9                      3.6627         8088239.0                  -83928.0
# 10                     3.2468        19667907.0                 -203878.0
# 11                     3.1284         6217637.0                  -64437.0
# 12                      2.626         4306454.0                  -44699.0
# 13                     2.3406        11883617.0                 -123333.0
# 14                     2.2648        14066277.0                 -146084.0
# 15                     2.0221         3712029.0                  -38434.0
# 16                     1.6506         4299097.0                  -44532.0
# 17                     1.5517        12746706.0                 -132279.0
# 18                     1.4009        17066677.0                 -177138.0
# 19                     1.3542        15151930.0                 -157210.0
# 20                     1.3273          374140.0                   -3920.0
# 21                     0.5063         7163278.0                  -74312.0
# 22                     0.2115           62900.0                    3800.0
# 23                     0.1908       52068324.23               13587774.91

# %%
XLE2 = XLE[~XLE['Holding_Name'].isin(list_values)].set_index('Holding_RIC')['Number_of_Shares'].sort_values().to_frame()
type(XLE2)
bar_plot = sns.barplot(x=XLE2.index, y=XLE2['Number_of_Shares'], color="#4CC9F0")
plt.xticks(rotation=90)
plt.show()

# %%
help(ld.get_data)
# Out:
# Help on function get_data in module lseg.data._access_layer.get_data_func:
#
# get_data(universe: Union[str, Iterable[str]], fields: Union[str, Iterable[str]], parameters: Union[str, dict, NoneType] = None, header_type: lseg.data.content._header_type.HeaderType = <HeaderType.TITLE: 2>) -> pandas.core.frame.DataFrame
#     Retrieves pricing snapshots, as well as Fundamental and Reference data.
#
#     Parameters
#     ----------
#     universe: str | list
#         Instruments to request
#     fields: str | list
#         Fields to request
#     parameters: str | dict, optional
#         Single key=value global parameter or dictionary of global parameters to request
#     header_type: HeaderType, default HeaderType.TITLE
#         If HeaderType.TITLE - returns field title as column headers for data
#         If HeaderType.NAME - returns field name as column headers for data
#         If HeaderType.NAME_AND_TITLE - returns field name and title as column headers for data
#
#     Returns
#     -------
#     pandas.DataFrame
#
#     Examples
#     --------
#     >>> get_data(universe=['IBM.N', 'VOD.L'], fields=['BID', 'ASK'])
#     >>> get_data(
#     ...     universe=['GOOG.O', 'AAPL.O'],
#     ...     fields=['TR.EV','TR.EVToSales'],
#     ...     parameters = {'SDate': '0CY', 'Curn': 'CAD'}
#     ... )

# %% [markdown]
# # Descargar series de tiempo

# %%
#help(rd.get_timeseries)

# %%
df_ts = ld.get_history(universe=["000001.SZ"], fields=["BID", "ASK"], interval="1D",
               start = "2016-06-13", end = "2024-07-20")

# %%
df_ts
# Out:
# 000001.SZ        BID       ASK
# Date
# 2016-06-13  8.599997   8.60833
# 2016-06-14   8.65833  8.666663
# 2016-06-15  8.699997   8.70833
# 2016-06-16      8.57      8.58
# 2016-06-17      8.57      8.58
# ...              ...       ...
# 2024-07-15     10.32     10.33
# 2024-07-16      10.3     10.31
# 2024-07-17     10.39      10.4
# 2024-07-18     10.41     10.42
# 2024-07-19     10.36     10.37
#
# [1971 rows x 2 columns]

# %%
import datetime as dt
today = dt.date.today()
delta_day = today - dt.timedelta(days=100)
print(today, d)
# Out:
# 2025-08-14 2025-05-06

# %%
df_ts = ld.get_history(universe=["000001.SZ"], fields=["BID", "ASK"], interval="1D",
               start = delta_day, end = today)
df_ts
# Out:
# 000001.SZ     BID    ASK
# Date
# 2025-05-06  10.95  10.96
# 2025-05-07  11.02  11.03
# 2025-05-08  11.07  11.08
# 2025-05-09  11.14  11.15
# 2025-05-12  11.16  11.17
# ...           ...    ...
# 2025-08-08  12.39   12.4
# 2025-08-11   12.3  12.31
# 2025-08-12  12.33  12.34
# 2025-08-13  12.25  12.26
# 2025-08-14  12.19   12.2
#
# [72 rows x 2 columns]

# %% [markdown]
# # Estadística Básica

# %%
dax_corto = dax['Instrument'][0:10].tolist()
dax_corto
# Out:
# ['BASFn.DE',
#  'IFXGn.DE',
#  'SIEGn.DE',
#  'EONGn.DE',
#  'DBKGn.DE',
#  'SATG_p.DE',
#  'SAPG.DE',
#  'BAYGn.DE',
#  'RWEG.DE',
#  'HNKG_p.DE']

# %%
w = ld.get_history('BASFn.DE', fields = ['ASK'],
                    start = delta_day, 
                    end = today, 
                    interval="1D")
Precios = w.rename(columns={'ASK': i})
Precios
# Out:
# BASFn.DE    005930.KS
# Date
# 2025-05-07      42.22
# 2025-05-08      42.79
# 2025-05-09      43.17
# 2025-05-12      44.66
# 2025-05-13      45.26
# ...               ...
# 2025-08-08      45.64
# 2025-08-11      44.74
# 2025-08-12      44.92
# 2025-08-13      45.57
# 2025-08-14      45.86
#
# [72 rows x 1 columns]

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in dax_corto[1:]:
    print(i)
    w = ld.get_history([i], fields = ['ASK'],
                          start = delta_day, 
                          end = today, 
                          interval="1D")
    w1 = w.rename(columns={'ASK': i})
    Precios = Precios.join(w1, lsuffix="_left", rsuffix="_right")
# Out:
# IFXGn.DE
# SIEGn.DE
# EONGn.DE
# DBKGn.DE
# SATG_p.DE
# SAPG.DE
# BAYGn.DE
# RWEG.DE
# HNKG_p.DE

# %%
Precios
# Out:
#             005930.KS  IFXGn.DE  SIEGn.DE  EONGn.DE  DBKGn.DE  SATG_p.DE  \
# Date
# 2025-05-07      42.22    30.225     209.6     15.74    23.555      226.7
# 2025-05-08      42.79      31.1    213.45    15.595    23.725      227.8
# 2025-05-09      43.17    31.535     214.4    15.525    24.165      229.3
# 2025-05-12      44.66    33.975     221.7    14.885     24.69      232.0
# 2025-05-13      45.26    34.635    223.95     14.68      24.7      233.6
# ...               ...       ...       ...       ...       ...        ...
# 2025-08-08      45.64    35.445     232.8     15.96     31.09      181.6
# 2025-08-11      44.74     35.29     227.3     15.92     31.11      184.0
# 2025-08-12      44.92     36.71     231.1     15.84     31.07      198.1
# 2025-08-13      45.57    36.685    230.35     16.03     30.94     197.35
# 2025-08-14      45.86     36.55    233.15     15.97    31.445     197.05
#
#             SAPG.DE  BAYGn.DE  RWEG.DE  HNKG_p.DE
# Date
# 2025-05-07   262.65     23.42    32.74      68.72
# 2025-05-08   263.25      23.4    32.68       68.4
# 2025-05-09    262.2     24.08    32.53      68.86
# 2025-05-12    262.8     23.99     32.5       70.8
# 2025-05-13   262.75      24.8     32.3      70.46
# ...             ...       ...      ...        ...
# 2025-08-08    250.3     25.71    36.01      69.86
# 2025-08-11    249.4    25.695    35.47      69.98
# 2025-08-12    232.6    25.995    35.52      71.42
# 2025-08-13   238.75     26.87    35.48      71.86
# 2025-08-14    239.7    26.595    34.44      71.52
#
# [72 rows x 10 columns]

# %%
Precios.describe()
# Out:
#        005930.KS  IFXGn.DE  SIEGn.DE   EONGn.DE   DBKGn.DE   SATG_p.DE  \
# count       72.0      72.0      72.0       72.0       72.0        72.0
# mean   43.055972    35.345  219.8625  15.660417  25.881944  209.897222
# std     1.228563  1.644348  5.750902   0.380715   2.174421   14.997154
# min        41.29    30.225    207.95      14.68     23.555      177.25
# 25%      42.0875   34.3975    215.95   15.41375   24.45375       201.1
# 50%       42.735   35.3275    219.35    15.6675      25.13       211.3
# 75%      43.6125  36.55625  223.7625    15.9475   25.97625     220.825
# max        45.92    38.555    233.15      16.51     31.445       233.6
#
#         SAPG.DE   BAYGn.DE    RWEG.DE  HNKG_p.DE
# count      72.0       72.0       72.0       72.0
# mean    257.675  26.213889  34.880972  68.716111
# std    8.361262    1.66841   1.580738   1.539602
# min       232.6      22.24       32.2       65.9
# 25%    251.5875   24.97375    33.2225      67.66
# 50%       259.3    26.4475      35.53       68.4
# 75%      263.65    27.4975     36.125      69.99
# max       272.4     29.205      37.71      71.86

# %%
Precios.columns
# Out:
# Index(['005930.KS', 'IFXGn.DE', 'SIEGn.DE', 'EONGn.DE', 'DBKGn.DE',
#        'SATG_p.DE', 'SAPG.DE', 'BAYGn.DE', 'RWEG.DE', 'HNKG_p.DE'],
#       dtype='object')

# %%
correlacion = Precios.corr()
print(correlacion)
# Out:
#            005930.KS  IFXGn.DE  SIEGn.DE  EONGn.DE  DBKGn.DE  SATG_p.DE  \
# 005930.KS   1.000000  0.069051  0.826233  0.056133  0.631139  -0.230399
# IFXGn.DE    0.069051  1.000000  0.414814  0.350788  0.139466  -0.135496
# SIEGn.DE    0.826233  0.414814  1.000000  0.277158  0.730943  -0.338624
# EONGn.DE    0.056133  0.350788  0.277158  1.000000  0.560594  -0.639849
# DBKGn.DE    0.631139  0.139466  0.730943  0.560594  1.000000  -0.744013
# SATG_p.DE  -0.230399 -0.135496 -0.338624 -0.639849 -0.744013   1.000000
# SAPG.DE    -0.376938  0.024272 -0.307521 -0.418522 -0.697424   0.565558
# BAYGn.DE    0.086147  0.545977  0.238298  0.499252  0.309658  -0.580384
# RWEG.DE     0.062947  0.575365  0.263463  0.713716  0.432402  -0.580396
# HNKG_p.DE   0.453308 -0.128597  0.391552 -0.270235  0.166291   0.128855
#
#             SAPG.DE  BAYGn.DE   RWEG.DE  HNKG_p.DE
# 005930.KS -0.376938  0.086147  0.062947   0.453308
# IFXGn.DE   0.024272  0.545977  0.575365  -0.128597
# SIEGn.DE  -0.307521  0.238298  0.263463   0.391552
# EONGn.DE  -0.418522  0.499252  0.713716  -0.270235
# DBKGn.DE  -0.697424  0.309658  0.432402   0.166291
# SATG_p.DE  0.565558 -0.580384 -0.580396   0.128855
# SAPG.DE    1.000000 -0.418956 -0.534603   0.248928
# BAYGn.DE  -0.418956  1.000000  0.805939  -0.494191
# RWEG.DE   -0.534603  0.805939  1.000000  -0.640135
# HNKG_p.DE  0.248928 -0.494191 -0.640135   1.000000

# %%
sns.heatmap(Precios.corr(), annot = True, fmt='.2g',cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
Seleccionar un índice o fondo 
Calcular el rendimiento del fondo o índice 
- 1 año para atrás hoy y 
- lo van comparar a 2 años atrás a 1 año
Filtro de Clenow a los instrumuentos que son más dinámicos del periodo 2 años atrás a 1 año (2021 a 2022)
- rendimientos en el periodo de 1 año para atrás hoy (2022 a 2023)

Si se cumple o no la hipotésis que plantea Clenow
