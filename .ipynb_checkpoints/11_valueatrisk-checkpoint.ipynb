# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from scipy.stats import norm
import requests
from io import StringIO
import seaborn as sns; sns.set()
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10,6)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
import os
os.environ["LD_LIB_CONFIG_PATH"] = "../../Configuration"

# %%
import lseg.data as ld
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x7f577413c4f0 {name='codebook'}>

# %%
mean = 0
std_dev = 1
x = np.arange(-5, 5, 0.01)
y = norm.pdf(x, mean, std_dev)
pdf = plt.plot(x, y)
min_ylim, max_ylim = plt.ylim()
plt.text(np.percentile(x, 5), max_ylim * 0.9, '95%:${:.4f}'
         .format(np.percentile(x, 5)))
plt.axvline(np.percentile(x, 5), color='r', linestyle='dashed',
            linewidth=4)
plt.title('Value at Risk Illustration')
plt.show()

# %%
RICS = ["GOLD.N", "MSFT.O", "NVDA.O"]
ts = ld.get_data(RICS,
                   [
                    'TR.PriceClose(SDate=2021-01-02,EDate=2025-04-22,Frq=D).date',
                    'TR.PriceClose(SDate=2021-01-02,EDate=2025-04-22,Frq=D)'
                   ])
ts2 = ts.drop_duplicates()
ts2
# Out:
#      Instrument       Date  Price Close
# 0        GOLD.N 2021-01-04    24.134819
# 1        GOLD.N 2021-01-05     23.80152
# 2        GOLD.N 2021-01-06    24.017184
# 3        GOLD.N 2021-01-07    24.281863
# 4        GOLD.N 2021-01-08    23.497629
# ...         ...        ...          ...
# 3232     NVDA.O 2025-04-14       110.71
# 3233     NVDA.O 2025-04-15        112.2
# 3234     NVDA.O 2025-04-16       104.49
# 3235     NVDA.O 2025-04-17       101.49
# 3236     NVDA.O 2025-04-21        96.91
#
# [3237 rows x 3 columns]

# %%
stocks = ts2.pivot(index="Date", columns="Instrument", values="Price Close")
stocks
# Out:
# Instrument     GOLD.N  MSFT.O    NVDA.O
# Date
# 2021-01-04  24.134819  217.69   13.1135
# 2021-01-05   23.80152   217.9  13.40475
# 2021-01-06  24.017184  212.25   12.6145
# 2021-01-07  24.281863  218.29    13.344
# 2021-01-08  23.497629  219.62  13.27675
# ...               ...     ...       ...
# 2025-04-14      20.41  387.81    110.71
# 2025-04-15      20.32  385.73     112.2
# 2025-04-16      20.65  371.61    104.49
# 2025-04-17      20.17  367.78    101.49
# 2025-04-21      20.45  359.12     96.91
#
# [1079 rows x 3 columns]

# %%
stocks_returns = (np.log(stocks) - np.log(stocks.shift(1))).dropna()
stocks_returns
# Out:
# Instrument    GOLD.N    MSFT.O    NVDA.O
# Date
# 2021-01-05 -0.013906  0.000964  0.021967
# 2021-01-06   0.00902 -0.026271 -0.060762
# 2021-01-07   0.01096   0.02806   0.05622
# 2021-01-08  -0.03283  0.006074 -0.005052
# 2021-01-11 -0.018952 -0.009746  0.025635
# ...              ...       ...       ...
# 2025-04-14 -0.008781 -0.001649 -0.001985
# 2025-04-15 -0.004419 -0.005378  0.013369
# 2025-04-16   0.01611 -0.037293 -0.071192
# 2025-04-17 -0.023519  -0.01036 -0.029131
# 2025-04-21  0.013787 -0.023828 -0.046178
#
# [1078 rows x 3 columns]

# %%
stocks_returns_mean = stocks_returns.mean()
weights  = np.random.random(len(stocks_returns.columns))
weights /= np.sum(weights)
#weights =  np.array([.333, .333, .333], dtype='float')
cov_var = stocks_returns.cov()
port_std = np.sqrt(weights.T.dot(cov_var).dot(weights))

# %%
weights
# Out:
# array([0.4992561 , 0.30299291, 0.19775099])

# %%
stocks_returns_mean
# Out:
# Instrument
# GOLD.N   -0.000154
# MSFT.O    0.000464
# NVDA.O    0.001855
# dtype: float64

# %%
print(stocks_returns_mean)
print(weights)
print(cov_var)
print(port_std)
# Out:
# Instrument
# GOLD.N   -0.000154
# MSFT.O    0.000464
# NVDA.O    0.001855
# dtype: float64
# [0.4992561  0.30299291 0.19775099]
# Instrument    GOLD.N    MSFT.O    NVDA.O
# Instrument
# GOLD.N      0.000435  0.000064  0.000100
# MSFT.O      0.000064  0.000280  0.000368
# NVDA.O      0.000100  0.000368  0.001169
# 0.01622278162381842

# %%
weights = np.array([.2,.3,.4])

# %%
stocks_returns_mean = stocks_returns.mean()
stocks_returns_mean
# Out:
# Instrument
# GOLD.N   -0.000154
# MSFT.O    0.000464
# NVDA.O    0.001855
# dtype: float64

# %%
initial_investment = 1000000
conf_level = 0.95

# %%
port_std = np.sqrt(weights.T.dot(cov_var).dot(weights))

# %%
port_std
# Out:
# 0.018486214334809993

# %%
alpha = norm.ppf(.05, stocks_returns_mean, port_std)

# %%
alpha
# Out:
# array([-0.0305608 , -0.02994275, -0.0285517 ])

# %%
stocks.columns
# Out:
# Index(['GOLD.N', 'MSFT.O', 'NVDA.O'], dtype='object', name='Instrument')

# %% [markdown]
# ## Variance-Covariance Method

# %%
for i, j in zip(stocks.columns, range(len(stocks.columns))):
    VaR_param = (initial_investment - initial_investment * 
                     (1 + alpha))[j]
    print("Parametric VaR result for {} is {} "
              .format(i, VaR_param))
# Out:
# Parametric VaR result for GOLD.N is 30560.80194898462
# Parametric VaR result for MSFT.O is 29942.752539458685
# Parametric VaR result for NVDA.O is 28551.69881333306

# %%
def VaR_parametric(initial_investment, conf_level):
    alpha = norm.ppf(1 - conf_level, stocks_returns_mean, port_std)
    for i, j in zip(stocks.columns, range(len(stocks.columns))):
        VaR_param = (initial_investment - initial_investment * 
                     (1 + alpha))[j]
        print("Parametric VaR result for {} is {} "
              .format(i, VaR_param))
    VaR_param = (initial_investment - initial_investment * (1 + alpha))
    print('--' * 25)
    return VaR_param

# %%
VaR_param = VaR_parametric(initial_investment, conf_level)
VaR_param
# Out:
# Parametric VaR result for GOLD.N is 30560.80194898462
# Parametric VaR result for MSFT.O is 29942.752539458685
# Parametric VaR result for NVDA.O is 28551.69881333306
# --------------------------------------------------
# array([30560.80194898, 29942.75253946, 28551.69881333])

# %%
var_horizon = []
time_horizon = 30
for j in range(len(stocks_returns.columns)):
    for i in range(1, time_horizon + 1):
        var_horizon.append(VaR_param[j] * np.sqrt(i))
plt.plot(var_horizon[:time_horizon], "o",
         c='blue', marker='*', label='GOLD')
plt.plot(var_horizon[time_horizon:time_horizon + 30], "o",
         c='green', marker='o', label='MSFT')
plt.plot(var_horizon[time_horizon + 30:time_horizon + 60], "o",
         c='red', marker='v', label='NVDA')
plt.xlabel("Days")
plt.ylabel("USD")
plt.title("VaR over 30-day period")
plt.legend()
plt.show()

# %% [markdown]
# ## Historical

# %%
for i, j in zip(stocks_returns.columns,
                    range(len(stocks_returns.columns))):
    print(np.percentile(stocks_returns.loc[:, i], 5))
# Out:
# -0.03305880153973695
# -0.02719548697164833
# -0.05369866864612218

# %%
stocks_returns.loc[:, 'NVDA.O']
# Out:
# Date
# 2021-01-05    0.021967
# 2021-01-06   -0.060762
# 2021-01-07     0.05622
# 2021-01-08   -0.005052
# 2021-01-11    0.025635
#                 ...
# 2025-04-14   -0.001985
# 2025-04-15    0.013369
# 2025-04-16   -0.071192
# 2025-04-17   -0.029131
# 2025-04-21   -0.046178
# Name: NVDA.O, Length: 1078, dtype: Float64

# %%
np.percentile(stocks_returns.loc[:, 'NVDA.O'], 5)
# Out:
# -0.05369866864612218

# %%
def VaR_historical(initial_investment, conf_level):
    Hist_percentile95 = []
    for i, j in zip(stocks_returns.columns,
                    range(len(stocks_returns.columns))):
        Hist_percentile95.append(np.percentile(stocks_returns.loc[:, i],
                                               5))
        print("Based on historical values 95% of {}'s return is {:.4f}"
              .format(i, Hist_percentile95[j]))
        VaR_historical = (initial_investment - initial_investment *
                          (1 + Hist_percentile95[j]))
        print("Historical VaR result for {} is {:.2f} "
              .format(i, VaR_historical))
        print('--' * 35)

# %%
VaR_historical(initial_investment,conf_level)
# Out:
# Based on historical values 95% of GOLD.N's return is -0.0331
# Historical VaR result for GOLD.N is 33058.80
# ----------------------------------------------------------------------
# Based on historical values 95% of MSFT.O's return is -0.0272
# Historical VaR result for MSFT.O is 27195.49
# ----------------------------------------------------------------------
# Based on historical values 95% of NVDA.O's return is -0.0537
# Historical VaR result for NVDA.O is 53698.67
# ----------------------------------------------------------------------

# %% [markdown]
# ## Monte Carlo VaR

# %%
x = np.random.uniform(-1, 1, 100) 
y = np.random.uniform(-1, 1, 100)

# %%
y
# Out:
# array([ 0.77292577, -0.21369997,  0.99418862,  0.02443341, -0.7932479 ,
#         0.26473866,  0.35200523, -0.64809038,  0.48629745, -0.52770959,
#         0.35326542, -0.30615351,  0.13681325, -0.99294776,  0.46445376,
#         0.72656771,  0.45900717,  0.38273611, -0.83234328,  0.71320033,
#        -0.39242382, -0.16078532, -0.04685637,  0.58295553, -0.95601129,
#        -0.84029532, -0.3125138 ,  0.95783497, -0.49811457, -0.07792891,
#         0.13182934,  0.28764694, -0.86890444, -0.89019653,  0.19253102,
#         0.30136747,  0.15446719, -0.49693746,  0.48845487, -0.04050444,
#         0.23401782, -0.27985719,  0.91882464,  0.06258433, -0.70589537,
#        -0.97646401, -0.14820162, -0.05078252, -0.99998882, -0.7692108 ,
#         0.63546407,  0.93590395,  0.48224363, -0.31648044,  0.02938524,
#         0.46127831, -0.22531027,  0.38856481, -0.27608807,  0.71654947,
#         0.76955846,  0.79702983, -0.97048676,  0.88807937, -0.59046686,
#         0.54068548,  0.27753913, -0.19338383,  0.49205147,  0.5304554 ,
#         0.0259425 ,  0.58540293, -0.4596313 , -0.9862117 , -0.32982767,
#        -0.49907036, -0.93541329, -0.57335391,  0.71606283, -0.46005686,
#        -0.83478474,  0.73066916, -0.44090354, -0.99113605,  0.39657807,
#        -0.75919916, -0.61688215,  0.9062526 ,  0.89844225, -0.0719241 ,
#         0.52808144, -0.52982839,  0.12243358,  0.490977  , -0.4542408 ,
#        -0.83855545,  0.5975397 ,  0.39931889,  0.79101672,  0.38732614])

# %%
x
# Out:
# array([ 0.95433355,  0.14174778, -0.45846971,  0.42563448, -0.28367748,
#        -0.43556245, -0.15981539, -0.33566046,  0.25768502,  0.27884789,
#        -0.05312575, -0.38705552,  0.07640424,  0.0671968 ,  0.69183963,
#        -0.04979096, -0.53671324,  0.74915226,  0.29148308,  0.02322664,
#         0.43155567,  0.1202196 ,  0.81343378,  0.6316021 ,  0.45927213,
#        -0.61993114,  0.16991826, -0.71680819,  0.85840166,  0.43372497,
#        -0.38829254, -0.48993535,  0.7989905 ,  0.35505377, -0.15741081,
#        -0.88748579, -0.53779634, -0.72216074,  0.19005757,  0.97318576,
#         0.76850463, -0.94044286, -0.28797287,  0.80752225,  0.55399768,
#        -0.67422374, -0.51137024, -0.67414793,  0.91767672,  0.92945943,
#         0.85561271, -0.96287503,  0.08525208, -0.43404232,  0.18821767,
#         0.51922826,  0.22244212,  0.70017397,  0.07386853, -0.13751814,
#         0.81847306, -0.32662403, -0.99773817, -0.48119046, -0.66329177,
#         0.82787675,  0.0142732 ,  0.17765546, -0.2619256 ,  0.40496207,
#         0.87327222,  0.50114302,  0.03333411,  0.50362859, -0.38894734,
#        -0.36013312, -0.77151867, -0.22013398,  0.29466869, -0.24641081,
#        -0.00678336,  0.40470608, -0.02212789,  0.30633133,  0.64652272,
#         0.04552044,  0.56181153, -0.29034261, -0.33712584, -0.47379048,
#        -0.33272029,  0.97667592,  0.96312794, -0.02924409,  0.92145095,
#        -0.49359221, -0.24664728, -0.43261745,  0.57591143, -0.54617862])

# %%
sample = 100    
def pi_calc(x, y):
    point_inside_circle = 0
    for i in range(sample):
        if np.sqrt(x[i] ** 2 + y[i] ** 2) <= 1:
            point_inside_circle += 1 
    print('pi value is {}'.format(4 * point_inside_circle/sample))

# %%
pi_calc(x,y)
# Out:
# pi value is 3.24

# %%
len(stocks.columns)
# Out:
# 3

# %%
sim_data = pd.DataFrame([])
num_reps = 1000
n = 100
for i in range(len(stocks.columns)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
sim_data = pd.DataFrame([])
num_reps = 1000
n = 100
for i in range(len(stocks.columns)):
    mean = np.random.randn(n).mean()
    std = np.random.randn(n).std()
    temp = pd.DataFrame(np.random.normal(mean, std, num_reps))
    sim_data = pd.concat([sim_data, temp], axis=1)
sim_data.columns = ['Simulation 1', 'Simulation 2', 'Simulation 3']

# %%
sim_data
# Out:
#      Simulation 1  Simulation 2  Simulation 3
# 0       -1.338488      0.178543      0.668309
# 1       -0.093733      0.698472      1.352746
# 2       -0.332316     -1.349801     -0.636204
# 3       -0.005861      1.112132      0.575556
# 4        0.584047      0.584992     -0.453433
# ..            ...           ...           ...
# 995      0.158534      0.214736      0.447641
# 996     -1.294302      0.610776     -0.657076
# 997     -0.242811      1.591443      0.297116
# 998      1.737079      0.733497     -0.101533
# 999     -0.342394     -1.191996      0.377217
#
# [1000 rows x 3 columns]

# %%
MC_percentile95 = []
for i, j in zip(sim_data.columns, range(len(sim_data.columns))):
    print(i,j)
# Out:
# Simulation 1 0
# Simulation 2 1
# Simulation 3 2

# %%
def MC_VaR(initial_investment, conf_level):
    MC_percentile95 = []
    for i, j in zip(sim_data.columns, range(len(sim_data.columns))):
        MC_percentile95.append(np.percentile(sim_data.loc[:, i], 5))
        print("Based on simulation 95% of {}'s return is {:.4f}"
              .format(i, MC_percentile95[j]))
        VaR_MC = (initial_investment - initial_investment * 
                  (1 + MC_percentile95[j]))
        print("Simulation VaR result for {} is {:.2f} "
              .format(i, VaR_MC))
        print('--' * 35)

# %%
MC_VaR(initial_investment, conf_level)
# Out:
# Based on simulation 95% of Simulation 1's return is -1.3147
# Simulation VaR result for Simulation 1 is 1314712.08
# ----------------------------------------------------------------------
# Based on simulation 95% of Simulation 2's return is -1.4269
# Simulation VaR result for Simulation 2 is 1426863.92
# ----------------------------------------------------------------------
# Based on simulation 95% of Simulation 3's return is -1.2813
# Simulation VaR result for Simulation 3 is 1281291.25
# ----------------------------------------------------------------------
